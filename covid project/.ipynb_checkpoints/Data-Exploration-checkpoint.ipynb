# %% [markdown]
# # **Analyzing COVID-19 data from January 2020 - December 2021**
# [data citation](https://www.kaggle.com/georgesaavedra/covid19-dataset)

# %%
import pandas as pd
import numpy as np
import datetime
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
data = pd.read_csv('./owid-covid-data.csv')

# %%
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
data
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 164249      ZWE    Africa     Zimbabwe  2022-02-20     233352.0      128.0
# 164250      ZWE    Africa     Zimbabwe  2022-02-21     233571.0      219.0
# 164251      ZWE    Africa     Zimbabwe  2022-02-22     233980.0      409.0
# 164252      ZWE    Africa     Zimbabwe  2022-02-23     234589.0      609.0
# 164253      ZWE    Africa     Zimbabwe  2022-02-24     234967.0      378.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 164249             281.571        5386.0         0.0                1.714
# 164250             281.143        5386.0         0.0                1.714
# 164251             339.571        5388.0         2.0                2.000
# 164252             339.429        5388.0         0.0                1.286
# 164253             338.429        5390.0         2.0                1.286
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 164249  ...             1.6          30.7                  36.791
# 164250  ...             1.6          30.7                  36.791
# 164251  ...             1.6          30.7                  36.791
# 164252  ...             1.6          30.7                  36.791
# 164253  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 164249                         1.7            61.49                    0.571
# 164250                         1.7            61.49                    0.571
# 164251                         1.7            61.49                    0.571
# 164252                         1.7            61.49                    0.571
# 164253                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 164249                                   NaN                          NaN
# 164250                                   NaN                          NaN
# 164251                                   NaN                          NaN
# 164252                                   NaN                          NaN
# 164253                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 164249               NaN                                      NaN
# 164250               NaN                                      NaN
# 164251               NaN                                      NaN
# 164252               NaN                                      NaN
# 164253               NaN                                      NaN
#
# [164254 rows x 67 columns]

# %% [markdown]
# #### **Trim the columns to just those of interest**

# %%
list(data.columns)
# Out:
# ['iso_code',
#  'continent',
#  'location',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'reproduction_rate',
#  'icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'new_tests',
#  'total_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_per_case',
#  'tests_units',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'total_boosters',
#  'new_vaccinations',
#  'new_vaccinations_smoothed',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'total_boosters_per_hundred',
#  'new_vaccinations_smoothed_per_million',
#  'new_people_vaccinated_smoothed',
#  'new_people_vaccinated_smoothed_per_hundred',
#  'stringency_index',
#  'population',
#  'population_density',
#  'median_age',
#  'aged_65_older',
#  'aged_70_older',
#  'gdp_per_capita',
#  'extreme_poverty',
#  'cardiovasc_death_rate',
#  'diabetes_prevalence',
#  'female_smokers',
#  'male_smokers',
#  'handwashing_facilities',
#  'hospital_beds_per_thousand',
#  'life_expectancy',
#  'human_development_index',
#  'excess_mortality_cumulative_absolute',
#  'excess_mortality_cumulative',
#  'excess_mortality',
#  'excess_mortality_cumulative_per_million']

# %%
dataTest = data[['continent', 'location', 'date', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'hospital_beds_per_thousand', 'life_expectancy', 'gdp_per_capita', 'reproduction_rate', 'extreme_poverty', 'population', 'median_age', 'people_vaccinated',
 'people_fully_vaccinated', 'cardiovasc_death_rate', 'diabetes_prevalence',]]

# %%
dataTest.head()
# Out:
#   continent     location        date  total_cases  new_cases  total_deaths  \
# 0      Asia  Afghanistan  2020-02-24          5.0        5.0           NaN
# 1      Asia  Afghanistan  2020-02-25          5.0        0.0           NaN
# 2      Asia  Afghanistan  2020-02-26          5.0        0.0           NaN
# 3      Asia  Afghanistan  2020-02-27          5.0        0.0           NaN
# 4      Asia  Afghanistan  2020-02-28          5.0        0.0           NaN
#
#    new_deaths  hospital_beds_per_thousand  life_expectancy  gdp_per_capita  \
# 0         NaN                         0.5            64.83        1803.987
# 1         NaN                         0.5            64.83        1803.987
# 2         NaN                         0.5            64.83        1803.987
# 3         NaN                         0.5            64.83        1803.987
# 4         NaN                         0.5            64.83        1803.987
#
#    reproduction_rate  extreme_poverty  population  median_age  \
# 0                NaN              NaN  39835428.0        18.6
# 1                NaN              NaN  39835428.0        18.6
# 2                NaN              NaN  39835428.0        18.6
# 3                NaN              NaN  39835428.0        18.6
# 4                NaN              NaN  39835428.0        18.6
#
#    people_vaccinated  people_fully_vaccinated  cardiovasc_death_rate  \
# 0                NaN                      NaN                597.029
# 1                NaN                      NaN                597.029
# 2                NaN                      NaN                597.029
# 3                NaN                      NaN                597.029
# 4                NaN                      NaN                597.029
#
#    diabetes_prevalence
# 0                 9.59
# 1                 9.59
# 2                 9.59
# 3                 9.59
# 4                 9.59

# %% [markdown]
# #### **Find the all unique dates**

# %%
dataTest['date'].unique()
# Out:
# array(['2020-02-24', '2020-02-25', '2020-02-26', '2020-02-27',
#        '2020-02-28', '2020-02-29', '2020-03-01', '2020-03-02',
#        '2020-03-03', '2020-03-04', '2020-03-05', '2020-03-06',
#        '2020-03-07', '2020-03-08', '2020-03-09', '2020-03-10',
#        '2020-03-11', '2020-03-12', '2020-03-13', '2020-03-14',
#        '2020-03-15', '2020-03-16', '2020-03-17', '2020-03-18',
#        '2020-03-19', '2020-03-20', '2020-03-21', '2020-03-22',
#        '2020-03-23', '2020-03-24', '2020-03-25', '2020-03-26',
#        '2020-03-27', '2020-03-28', '2020-03-29', '2020-03-30',
#        '2020-03-31', '2020-04-01', '2020-04-02', '2020-04-03',
#        '2020-04-04', '2020-04-05', '2020-04-06', '2020-04-07',
#        '2020-04-08', '2020-04-09', '2020-04-10', '2020-04-11',
#        '2020-04-12', '2020-04-13', '2020-04-14', '2020-04-15',
#        '2020-04-16', '2020-04-17', '2020-04-18', '2020-04-19',
#        '2020-04-20', '2020-04-21', '2020-04-22', '2020-04-23',
#        '2020-04-24', '2020-04-25', '2020-04-26', '2020-04-27',
#        '2020-04-28', '2020-04-29', '2020-04-30', '2020-05-01',
#        '2020-05-02', '2020-05-03', '2020-05-04', '2020-05-05',
#        '2021-11-13', '2021-11-14', '2021-11-15', '2021-11-16',
#        '2021-11-17', '2021-11-18', '2021-11-19', '2021-11-20',
#        '2021-11-21', '2021-11-22', '2021-11-23', '2021-11-24',
#        '2021-11-25', '2021-11-26', '2021-11-27', '2021-11-28',
#        '2021-11-29', '2021-11-30', '2021-12-01', '2021-12-02',
#        '2021-12-03', '2021-12-04', '2021-12-05', '2021-12-06',
#        '2021-12-07', '2021-12-08', '2021-12-09', '2021-12-10',
#        '2021-12-11', '2021-12-12', '2021-12-13', '2021-12-14',
#        '2021-12-15', '2021-12-16', '2021-12-17', '2021-12-18',
#        '2021-12-19', '2021-12-20', '2021-12-21', '2021-12-22',
#        '2021-12-23', '2021-12-24', '2021-12-25', '2021-12-26',
#        '2021-12-27', '2021-12-28', '2021-12-29', '2021-12-30',
#        '2021-12-31', '2022-01-01', '2022-01-02', '2022-01-03',
#        '2022-01-04', '2022-01-05', '2022-01-06', '2022-01-07',
#        '2022-01-08', '2022-01-09', '2022-01-10', '2022-01-11',
#        '2022-01-12', '2022-01-13', '2022-01-14', '2022-01-15',
#        '2022-01-16', '2022-01-17', '2022-01-18', '2022-01-19',
#        '2022-01-20', '2022-01-21', '2022-01-22', '2022-01-23',
#        '2022-01-24', '2022-01-25', '2022-01-26', '2022-01-27',
#        '2022-01-28', '2022-01-29', '2022-01-30', '2022-01-31',
#        '2022-02-01', '2022-02-02', '2022-02-03', '2022-02-04',
#        '2022-02-05', '2022-02-06', '2022-02-07', '2022-02-08',
#        '2022-02-09', '2022-02-10', '2022-02-11', '2022-02-12',
#        '2022-02-13', '2022-02-14', '2022-02-15', '2022-02-16',
#        '2022-02-17', '2022-02-18', '2022-02-19', '2022-02-20',
#        '2022-02-21', '2022-02-22', '2022-02-23', '2022-02-24',
#        '2020-02-13', '2020-02-14', '2020-02-15', '2020-02-16',
#        '2020-02-17', '2020-02-18', '2020-02-19', '2020-02-20',
#        '2020-02-21', '2020-02-22', '2020-02-23', '2020-01-01',
#        '2020-01-02', '2020-01-03', '2020-01-04', '2020-01-05',
#        '2020-01-06', '2020-01-07', '2020-01-08', '2020-01-09',
#        '2020-01-10', '2020-01-11', '2020-01-12', '2020-01-13',
#        '2020-01-14', '2020-01-15', '2020-01-16', '2020-01-17',
#        '2020-01-18', '2020-01-19', '2020-01-20', '2020-01-21',
#        '2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25',
#        '2020-01-26', '2020-01-27', '2020-01-28', '2020-01-29',
#        '2020-01-30', '2020-01-31', '2020-02-01', '2020-02-02',
#        '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06',
#        '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10',
#        '2020-02-11', '2020-02-12'], dtype=object)

# %%
dataTest['date'].describe()
# Out:
# count         164254
# unique           786
# top       2021-08-27
# freq             238
# Name: date, dtype: object

# %% [markdown]
# #### **Split up the date column**

# %%
df = dataTest['date'].str.split('-', expand = True)

# %%
df.head()
# Out:
#       0   1   2
# 0  2020  02  24
# 1  2020  02  25
# 2  2020  02  26
# 3  2020  02  27
# 4  2020  02  28

# %% [markdown]
# #### **Rename the dataframe columns**

# %%
df1 = df.rename(columns={0: 'year', 1: 'month', 2: 'day'})

# %%
df1.head()
# Out:
#    year month day
# 0  2020    02  24
# 1  2020    02  25
# 2  2020    02  26
# 3  2020    02  27
# 4  2020    02  28

# %% [markdown]
# #### **Bring back into the original dataset**

# %%
MDYdf = pd.concat([dataTest, df1], axis =1)

# %%
MDYdf.head()
# Out:
#   continent     location        date  total_cases  new_cases  total_deaths  \
# 0      Asia  Afghanistan  2020-02-24          5.0        5.0           NaN
# 1      Asia  Afghanistan  2020-02-25          5.0        0.0           NaN
# 2      Asia  Afghanistan  2020-02-26          5.0        0.0           NaN
# 3      Asia  Afghanistan  2020-02-27          5.0        0.0           NaN
# 4      Asia  Afghanistan  2020-02-28          5.0        0.0           NaN
#
#    new_deaths  hospital_beds_per_thousand  life_expectancy  gdp_per_capita  \
# 0         NaN                         0.5            64.83        1803.987
# 1         NaN                         0.5            64.83        1803.987
# 2         NaN                         0.5            64.83        1803.987
# 3         NaN                         0.5            64.83        1803.987
# 4         NaN                         0.5            64.83        1803.987
#
#    ...  extreme_poverty  population  median_age  people_vaccinated  \
# 0  ...              NaN  39835428.0        18.6                NaN
# 1  ...              NaN  39835428.0        18.6                NaN
# 2  ...              NaN  39835428.0        18.6                NaN
# 3  ...              NaN  39835428.0        18.6                NaN
# 4  ...              NaN  39835428.0        18.6                NaN
#
#    people_fully_vaccinated  cardiovasc_death_rate  diabetes_prevalence  year  \
# 0                      NaN                597.029                 9.59  2020
# 1                      NaN                597.029                 9.59  2020
# 2                      NaN                597.029                 9.59  2020
# 3                      NaN                597.029                 9.59  2020
# 4                      NaN                597.029                 9.59  2020
#
#   month day
# 0    02  24
# 1    02  25
# 2    02  26
# 3    02  27
# 4    02  28
#
# [5 rows x 21 columns]

# %% [markdown]
# #### **Group by the geographic area**

# %%
MDYdf1 = MDYdf.groupby('location').median()

# %%
MDYdf1.head()
# Out:
#              total_cases  new_cases  total_deaths  new_deaths  \
# location
# Afghanistan      55655.0       77.0        2451.0         4.0
# Africa         3804761.0    11302.0      104384.0       274.0
# Albania         109248.5      183.5        1866.0         4.0
# Algeria         112461.0      240.0        3002.0         8.0
# Andorra          10849.0       12.0         112.0         0.0
#
#              hospital_beds_per_thousand  life_expectancy  gdp_per_capita  \
# location
# Afghanistan                        0.50            64.83        1803.987
# Africa                              NaN              NaN             NaN
# Albania                            2.89            78.57       11803.431
# Algeria                            1.90            76.88       13913.839
# Andorra                             NaN            83.73             NaN
#
#              reproduction_rate  extreme_poverty    population  median_age  \
# location
# Afghanistan               1.02              NaN  3.983543e+07        18.6
# Africa                     NaN              NaN  1.373486e+09         NaN
# Albania                   1.04              1.1  2.872934e+06        38.0
# Algeria                   1.02              0.5  4.461663e+07        29.1
# Andorra                   0.99              NaN  7.735400e+04         NaN
#
#              people_vaccinated  people_fully_vaccinated  \
# location
# Afghanistan           735213.0                 324951.5
# Africa              47272050.0               28638137.0
# Albania               804881.0                 652115.5
# Algeria              6409018.0                5114493.5
# Andorra                32590.5                  26811.5
#
#              cardiovasc_death_rate  diabetes_prevalence
# location
# Afghanistan                597.029                 9.59
# Africa                         NaN                  NaN
# Albania                    304.195                10.08
# Algeria                    278.364                 6.73
# Andorra                    109.135                 7.97
