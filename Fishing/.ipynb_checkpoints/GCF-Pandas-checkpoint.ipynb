# %%
## import package(s)


import pandas as pd

# %%
## read in data

data = pd.read_excel('Reference.xlsx', header = [0])

data
# Out:
#               Reference                  Unnamed: 1          Unnamed: 2  \
# 0                  Name                FMP Category    Aggregation Type
# 1           Almaco Jack                   Reef Fish               Mixed
# 2            Black Drum       Not Federally Managed               Mixed
# 3         Black Grouper                   Reef Fish           Transient
# 4        Cubera Snapper                   Reef Fish           Transient
# 5                   Gag                   Reef Fish           Transient
# 6       Goliath Grouper                   Reef Fish           Transient
# 7      Gray Triggerfish                   Reef Fish            Resident
# 8     Greater Amberjack                   Reef Fish               Mixed
# 9               Hogfish                   Reef Fish            Resident
# 10        King Mackerel  Coastal Migratory Pelagics    Simple Migratory
# 11       Mutton Snapper                   Reef Fish           Transient
# ...

# %%
## copy of the data

df = data.copy()

df
# Out:
#               Reference                  Unnamed: 1          Unnamed: 2  \
# 0                  Name                FMP Category    Aggregation Type
# 1           Almaco Jack                   Reef Fish               Mixed
# 2            Black Drum       Not Federally Managed               Mixed
# 3         Black Grouper                   Reef Fish           Transient
# 4        Cubera Snapper                   Reef Fish           Transient
# 5                   Gag                   Reef Fish           Transient
# 6       Goliath Grouper                   Reef Fish           Transient
# 7      Gray Triggerfish                   Reef Fish            Resident
# 8     Greater Amberjack                   Reef Fish               Mixed
# 9               Hogfish                   Reef Fish            Resident
# 10        King Mackerel  Coastal Migratory Pelagics    Simple Migratory
# 11       Mutton Snapper                   Reef Fish           Transient
# ...

# %%
## set the header to the first row (column names)

dfCol = df.rename(columns=df.iloc[0]).drop(df.index[0])

# %%
dfCol
# Out:
#                    Name                FMP Category    Aggregation Type  \
# 1           Almaco Jack                   Reef Fish               Mixed
# 2            Black Drum       Not Federally Managed               Mixed
# 3         Black Grouper                   Reef Fish           Transient
# 4        Cubera Snapper                   Reef Fish           Transient
# 5                   Gag                   Reef Fish           Transient
# 6       Goliath Grouper                   Reef Fish           Transient
# 7      Gray Triggerfish                   Reef Fish            Resident
# 8     Greater Amberjack                   Reef Fish               Mixed
# 9               Hogfish                   Reef Fish            Resident
# 10        King Mackerel  Coastal Migratory Pelagics    Simple Migratory
# 11       Mutton Snapper                   Reef Fish           Transient
# 12       Nassau Grouper                   Reef Fish           Transient
# ...

# %%
## information about the data

dfCol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 1 to 28
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Name                            28 non-null     object
#  1   FMP Category                    28 non-null     object
#  2   Aggregation Type                28 non-null     object
#  3   Spawning Season Duration (1-4)  28 non-null     object
#  4   Density Change (1-4)            28 non-null     object
#  5   Max Age (yr)                    28 non-null     object
#  6   Max Weight (kg)                 28 non-null     object
#  7   Max Length (cm)                 28 non-null     object
#  8   K vB Growth Coeff.              28 non-null     object
#  9   Linf Asym. Length (cm)          28 non-null     object
#  10  Age at length 0 (yr)            28 non-null     object
#  11  Age at Maturity (months)        28 non-null     object
# ...
